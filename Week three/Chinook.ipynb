# %% [markdown]
# # The Chinook Store Analysis

# %% [markdown]
# I will be assisting the Chinook team with understanding the media in their store, their customers and employees, and their invoice information by answering some questions.

# %%
# import packages
import pandas as pd
import numpy as np

# %%
# reading in datasets
Album = pd.read_csv("result/Album.csv")
Artist = pd.read_csv("result/Artist.csv")
Customer = pd.read_csv("result/Customer.csv")
Employee = pd.read_csv("result/Employee.csv")
Genre = pd.read_csv("result/Genre.csv")
Invoice = pd.read_csv("result/Invoice.csv")
InvoiceLine = pd.read_csv("result/InvoiceLine.csv")
MediaType = pd.read_csv("result/MediaType.csv")
Playlist  = pd.read_csv("result/Playlist.csv")
PlaylistTrack = pd.read_csv("result/PlaylistTrack.csv")
Track = pd.read_csv("result/Track.csv")

# %% [markdown]
# View the first 5 rows of each entry.

# %%
# Table of Albuml
Album.head()
# Out:
#    AlbumId                                  Title  ArtistId
# 0        1  For Those About To Rock We Salute You         1
# 1        2                      Balls to the Wall         2
# 2        3                      Restless and Wild         2
# 3        4                      Let There Be Rock         1
# 4        5                               Big Ones         3

# %%
#Table for artist
Artist.head()
# Out:
#    ArtistId               Name
# 0         1              AC/DC
# 1         2             Accept
# 2         3          Aerosmith
# 3         4  Alanis Morissette
# 4         5    Alice In Chains

# %%
# Table for customers
Customer.head()
# Out:
#    CustomerId  FirstName     LastName  \
# 0           1       Luís    Gonçalves
# 1           2     Leonie       Köhler
# 2           3   François     Tremblay
# 3           4      Bjørn       Hansen
# 4           5  František  Wichterlová
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                  JetBrains s.r.o.
#
#                            Address                 City State         Country  \
# 0  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP          Brazil
# 1          Theodor-Heuss-Straße 34            Stuttgart   NaN         Germany
# 2                1498 rue Bélanger             Montréal    QC          Canada
# 3                 Ullevålsveien 14                 Oslo   NaN          Norway
# ...

# %%
# Employee table
Employee.head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  BirthDate  \
# 0           1    Adams    Andrew      General Manager        NaN        NaN
# 1           2  Edwards     Nancy        Sales Manager        1.0        NaN
# 2           3  Peacock      Jane  Sales Support Agent        2.0        NaN
# 3           4     Park  Margaret  Sales Support Agent        2.0        NaN
# 4           5  Johnson     Steve  Sales Support Agent        2.0        NaN
#
#    HireDate              Address      City State Country PostalCode  \
# 0       NaN  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 1       NaN         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3
# 2       NaN        1111 6 Ave SW   Calgary    AB  Canada    T2P 5M5
# 3       NaN     683 10 Street SW   Calgary    AB  Canada    T2P 5G3
# 4       NaN         7727B 41 Ave   Calgary    AB  Canada    T3B 1Y7
#
#                Phone                Fax                     Email
# ...

# %%
Genre.head()
# Out:
#    GenreId                Name
# 0        1                Rock
# 1        2                Jazz
# 2        3               Metal
# 3        4  Alternative & Punk
# 4        5       Rock And Roll

# %%
Invoice.head()
# Out:
#    InvoiceId  CustomerId  InvoiceDate           BillingAddress BillingCity  \
# 0          1           2          NaN  Theodor-Heuss-Straße 34   Stuttgart
# 1          2           4          NaN         Ullevålsveien 14        Oslo
# 2          3           8          NaN          Grétrystraat 63    Brussels
# 3          4          14          NaN           8210 111 ST NW    Edmonton
# 4          5          23          NaN          69 Salem Street      Boston
#
#   BillingState BillingCountry BillingPostalCode  Total
# 0          NaN        Germany             70174   1.98
# 1          NaN         Norway              0171   3.96
# 2          NaN        Belgium              1000   5.94
# 3           AB         Canada           T6G 2C7   8.91
# 4           MA            USA              2113  13.86

# %%
InvoiceLine.head()
# Out:
#    InvoiceLineId  InvoiceId  TrackId  UnitPrice  Quantity
# 0              1          1        2       0.99         1
# 1              2          1        4       0.99         1
# 2              3          2        6       0.99         1
# 3              4          2        8       0.99         1
# 4              5          2       10       0.99         1

# %%
MediaType.head()
# Out:
#    MediaTypeId                         Name
# 0            1              MPEG audio file
# 1            2     Protected AAC audio file
# 2            3  Protected MPEG-4 video file
# 3            4     Purchased AAC audio file
# 4            5               AAC audio file

# %%
Playlist.head()
# Out:
#    PlaylistId        Name
# 0           1       Music
# 1           2      Movies
# 2           3    TV Shows
# 3           4  Audiobooks
# 4           5  90’s Music

# %%
PlaylistTrack.head()
# Out:
#    PlaylistId  TrackId
# 0           1        1
# 1           1        2
# 2           1        3
# 3           1        4
# 4           1        5

# %%
Track.head()
# Out:
#    TrackId                                     Name  AlbumId  MediaTypeId  \
# 0        1  For Those About To Rock (We Salute You)        1            1
# 1        2                        Balls to the Wall        2            2
# 2        3                          Fast As a Shark        3            2
# 3        4                        Restless and Wild        3            2
# 4        5                     Princess of the Dawn        3            2
#
#    GenreId                                           Composer  Milliseconds  \
# 0        1          Angus Young, Malcolm Young, Brian Johnson        343719
# 1        1                                                NaN        342562
# 2        1  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# 3        1  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051
# 4        1                         Deaffy & R.A. Smith-Diesel        375418
#
#       Bytes  UnitPrice
# 0  11170334       0.99
# ...

# %% [markdown]
#     QUESTION ONE.We would like to throw a promotional Music Festival in the city we made the most money. Write a query that returns the 1 city that has the highest sum of invoice totals. Return both the city name and 	the sum of all invoice totals.Which city has the best customers?

# %%
Best_customers = Invoice.groupby("BillingCity")["Total"].sum()
Best_customers.sort_values(ascending=False)[:1]
# Out:
# BillingCity
# Prague    90.24
# Name: Total, dtype: float64

# %% [markdown]
# From the query above, Prague has highest sum of invoice totals.

# %% [markdown]
# Question Two.
# Which countries have the most Invoices?
# Use the Invoice table to determine the countries that have the most invoices.Provide a table of BillingCountry and Invoices ordered by the number of invoices for each country.The country with the most invoices should appear first.

# %%
Country_invoices = Invoice.groupby("BillingCountry").count()
Country_invoices.sort_values("InvoiceId",ascending=False)
# Out:
#                 InvoiceId  CustomerId  InvoiceDate  BillingAddress  \
# BillingCountry
# USA                    91          91            0              91
# Canada                 56          56            0              56
# Brazil                 35          35            0              35
# France                 35          35            0              35
# Germany                28          28            0              28
# United Kingdom         21          21            0              21
# Czech Republic         14          14            0              14
# Portugal               14          14            0              14
# India                  13          13            0              13
# Italy                   7           7            0               7
# Sweden                  7           7            0               7
# Spain                   7           7            0               7
# Poland                  7           7            0               7
# ...

# %% [markdown]
# USA Is the country with the most invoices.

# %% [markdown]
# Question Three.
# Who is the best customer?
# The customer who has spent the most money will be declared the best customer. Build a query that returns the person who has spent the most money

# %%
# joining both customer and invoice tables
customer_invoice =  Invoice.join(Customer,lsuffix = '_invoice',rsuffix = '_customer',how = "inner")
customer_invoice.head()
# Out:
#    InvoiceId  CustomerId_invoice  InvoiceDate           BillingAddress  \
# 0          1                   2          NaN  Theodor-Heuss-Straße 34
# 1          2                   4          NaN         Ullevålsveien 14
# 2          3                   8          NaN          Grétrystraat 63
# 3          4                  14          NaN           8210 111 ST NW
# 4          5                  23          NaN          69 Salem Street
#
#   BillingCity BillingState BillingCountry BillingPostalCode  Total  \
# 0   Stuttgart          NaN        Germany             70174   1.98
# 1        Oslo          NaN         Norway              0171   3.96
# 2    Brussels          NaN        Belgium              1000   5.94
# 3    Edmonton           AB         Canada           T6G 2C7   8.91
# 4      Boston           MA            USA              2113  13.86
#
#    CustomerId_customer  ...                                           Company  \
# ...

# %%
Best_customer = customer_invoice.groupby("FirstName")["Total"].sum()
Best_customer.sort_values(ascending=False)
# Out:
# FirstName
# Tim          13.86
# Lucas        13.86
# Steve        13.86
# Ellie        13.86
# Roberto      13.86
# Richard      13.86
# František    13.86
# Dominique    13.86
# Frank         9.90
# Hugh          8.91
# Victor        8.91
# Michelle      8.91
# Aaron         8.91
# Camille       8.91
# Bjørn         8.91
# Alexandre     8.91
# Phil          8.91
# Jack          5.94
# Ladislav      5.94
# François      5.94
# Martha        5.94
# Emma          5.94
# Eduardo       5.94
# Niklas        5.94
# Puja          5.94
# Edward        3.96
# Fynn          3.96
# Joakim        3.96
# John          3.96
# Terhi         3.96
# Kara          3.96
# Leonie        3.96
# Manoj         3.96
# Mark          2.97
# Enrique       1.98
# Madalena      1.98
# Astrid        1.98
# Stanisław     1.98
# Robert        1.98
# Daan          1.98
# Diego         1.98
# Wyatt         1.98
# Luís          1.98
# Luis          1.98
# Kathy         1.98
# Hannah        1.98
# Heather       1.98
# ...

# %% [markdown]
# The Best customer is Tim

# %% [markdown]
# Question four
# We want to find out the most popular music Genre for each country.We determine the most popular genre as the genre with the highest amount of purchases. Write a query that returns each country along with the top Genre. For countries where the maximum number of purchases is shared return all Genres.For this query, you will need to use the Invoice, InvoiceLine, Customer, Track, and Genre tables.

# %%
track_genre = Track.join(Genre,on = 'TrackId',lsuffix = '_track',rsuffix = '_genre',how = "inner")
track_genre.head()
# Out:
#    TrackId                               Name_track  AlbumId  MediaTypeId  \
# 0        1  For Those About To Rock (We Salute You)        1            1
# 1        2                        Balls to the Wall        2            2
# 2        3                          Fast As a Shark        3            2
# 3        4                        Restless and Wild        3            2
# 4        5                     Princess of the Dawn        3            2
#
#    GenreId_track                                           Composer  \
# 0              1          Angus Young, Malcolm Young, Brian Johnson
# 1              1                                                NaN
# 2              1  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...
# 3              1  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...
# 4              1                         Deaffy & R.A. Smith-Diesel
#
#    Milliseconds     Bytes  UnitPrice  GenreId_genre          Name_genre
# ...

# %% [markdown]
# joined the Track and Genre Tables

# %%
invoice_il = Invoice.join(InvoiceLine,on = 'InvoiceId',lsuffix = '_i',rsuffix = '_il',how = "inner")
invoice_il.head()
# Out:
#    InvoiceId  InvoiceId_i  CustomerId  InvoiceDate           BillingAddress  \
# 0          1            1           2          NaN  Theodor-Heuss-Straße 34
# 1          2            2           4          NaN         Ullevålsveien 14
# 2          3            3           8          NaN          Grétrystraat 63
# 3          4            4          14          NaN           8210 111 ST NW
# 4          5            5          23          NaN          69 Salem Street
#
#   BillingCity BillingState BillingCountry BillingPostalCode  Total  \
# 0   Stuttgart          NaN        Germany             70174   1.98
# 1        Oslo          NaN         Norway              0171   3.96
# 2    Brussels          NaN        Belgium              1000   5.94
# 3    Edmonton           AB         Canada           T6G 2C7   8.91
# 4      Boston           MA            USA              2113  13.86
#
#    InvoiceLineId  InvoiceId_il  TrackId  UnitPrice  Quantity
# ...

# %% [markdown]
# I joined invoice and InvoiceLine tables

# %%
invoice_track = invoice_il.join(track_genre,on = "TrackId",lsuffix = '_ii',rsuffix = '_tg',how = "inner")
invoice_track.head(3)
# Out:
#    TrackId  InvoiceId  InvoiceId_i  CustomerId  InvoiceDate  \
# 0        4          1            1           2          NaN
# 1        6          2            2           4          NaN
# 2        8          3            3           8          NaN
#
#             BillingAddress BillingCity BillingState BillingCountry  \
# 0  Theodor-Heuss-Straße 34   Stuttgart          NaN        Germany
# 1         Ullevålsveien 14        Oslo          NaN         Norway
# 2          Grétrystraat 63    Brussels          NaN        Belgium
#
#   BillingPostalCode  ...            Name_track  AlbumId  MediaTypeId  \
# 0             70174  ...  Princess of the Dawn        3            2
# 1              0171  ...       Let's Get It Up        1            1
# 2              1000  ...            Snowballed        1            1
#
#    GenreId_track                                   Composer  Milliseconds  \
# 0              1                 Deaffy & R.A. Smith-Diesel        375418
# ...

# %% [markdown]
# I joined the invoice_track and track_genre tables

# %%
country_genre = invoice_track.join(Customer, on = "CustomerId",lsuffix = '_it',rsuffix = '_c',how = "inner")
country_genre.head(1)
# Out:
#    CustomerId  TrackId  InvoiceId  InvoiceId_i  CustomerId_it  InvoiceDate  \
# 0           2        4          1            1              2          NaN
#
#             BillingAddress BillingCity BillingState BillingCountry  ...  \
# 0  Theodor-Heuss-Straße 34   Stuttgart          NaN        Germany  ...
#
#   Company            Address      City  State  Country  PostalCode  \
# 0     NaN  1498 rue Bélanger  Montréal     QC   Canada     H2G 1A7
#
#                Phone  Fax                Email  SupportRepId
# 0  +1 (514) 721-4711  NaN  ftremblay@gmail.com             3
#
# [1 rows x 41 columns]

# %% [markdown]
# I joined the invoice_track and Customer tables

# %%
genres = country_genre[["Country","Name_genre","Total"]].groupby(["Country","Name_genre"])["Total"].sum()
genres.sort_values(ascending=False)
# Out:
# Country         Name_genre
# USA             R&B/Soul           13.86
# Canada          Easy Listening      8.91
# Denmark         Soundtrack          5.94
# Czech Republic  Reggae              3.96
# France          Comedy              1.98
# Canada          Blues               1.98
# Germany         Science Fiction     0.99
# Name: Total, dtype: float64

# %% [markdown]
# Most popular music Genre for each country.
